# %%
### Libraries
using LinearAlgebra
using DelimitedFiles
using DifferentialEquations
using Tullio
⊗(A,B) = kron(A,B) ;

# %% [markdown]
# ### Initial parameters

# %%
### Constants
MBOHR = 5.788381e-5         ### Bohrs magneton
KB = 8.6173324e-5           ### Bolzmann factor
GAMMA_R = 1.760859644e-4    ### Gyromagnetic ratio ##1 for units of G_r=1
hbar = 1.0#0.658211928e0        ### Planck constant (eV*fs) 
k_Boltzman = 0.00008617343 ;#(eV/K) # 1.3806504d-23 (J/K)
KB = 8.6173324e-5
### Parameters and initiallizations
ny = 1
nx = 2
ns = nx*ny
nσ = 2
nk = 20  ##### This is going to be transformed into the number of poles 
nα = 2
t = 1
γ = 1
γso = 0.0
γc = 1.0
ϵ0 = 0.0#2γ
j_sd = 0.1#0.1
Δ_α = [0.,0.]
Temp = 300
β = 1/(k_Boltzman*Temp)
### Dimensions of the problem
dim_s = ns*nσ#(nx*ns,nx*ns)
dim_e = nk*nσ
dim_α = nα
dims_Gleαs_kαij=(dim_e,dim_α,dim_s,dim_s)
dims_Gls_ij = (dim_s,dim_s)
size_Gleαs_kαij = prod(dims_Gleαs_kαij) 
size_Gls_ij = prod(dims_Gls_ij)
### Pauli matrices
σ_0 = Matrix{ComplexF64}([1. 0. ; 0 1])
σ_x =  Matrix{ComplexF64}([0 1; 1 0])
σ_y =  Matrix{ComplexF64}([0 -1im ; 1im 0 ])
σ_z = Matrix{ComplexF64}([1 0. ; 0. -1])

I_a1b1 = Matrix{ComplexF64}(I, ns, ns)           # Identity on lattice space
I_ab = Matrix{ComplexF64}(I, nσ*ns, nσ*ns)        # Identity on lattice ⊗ spin
# --- Pauli matrices extended to the full Hilbert space ---
σ_x1ab = kron(I_a1b1, σ_x)
σ_x2ab = kron(I_a1b1, σ_y)
σ_x3ab = kron(I_a1b1, σ_z)
# --- Pauli matrices as a 3D array σ_abx[μ, i, j] ---
σ_ijx = cat(σ_x1ab, σ_x2ab, σ_x3ab; dims=3)
### Hamiltonians
hs_ij = zeros(ComplexF64, (dim_s,dim_s) )
# heα_kα = zeros(ComplexF64, (dim_e,dim_α ))
# heαs_kαi = zeros(ComplexF64, (dim_e,dim_α,dim_s) )
# hseα_ikα = zeros(ComplexF64, (dim_s,dim_e,dim_α) )
### Green functions
#gl_kα = zeros(ComplexF64, (dim_e,dim_α) )
### Dynamical variables
Gleαs_kαij = zeros(ComplexF64, dims_Gleαs_kαij  )
Gls_ij = zeros(ComplexF64, dims_Gls_ij );
### Observables

# %%
#I_ab

# %%
#Gleαs_kαij

# %% [markdown]
# #### Pulses

# %%
# ### Leviton 
# ts = 0.0:0.1:200
# τ = 6
# t0 = 80
# lev(t;t0 = t0,τ = τ) = 2τ/((t-t0)^2+τ^2)
# plt.plot(ts,lev.(ts))

# %%
#gauss(t;A,t0,τ)=A*exp(-(t-t0)^2/(2*τ^2))

# %%
#### Initiallizing the dynamical variables 
# σ_ijx 
# σ_x3ab
#LinRange(-pi,pi,nk)
#heα_kα[2:2:end,1]
#### Calculation of the self-energy 
function selfenergy(ϵ;γ=γ,γc=γc)# thop = thop, t_ls = 1.) 
    ### Note that this configuration for the self energy can be modified later
    #thop = global_var.thop
    Δ = 4 * γ^2 - ϵ^2
    if real(Δ) > 0
        Σ = ϵ - im * sqrt(Δ)
    else
        if real(ϵ) > 0
            sgn = 1
        else
            sgn = -1
        end
        Σ = ϵ - sgn * sqrt(-Δ)
    end
    Σ = Σ* (γc^2 / (2 * γ^2))
    return Σ
end
function Gamma_ϵ(ϵ;γ=γ,γc=γc)#
    -2*imag(selfenergy(ϵ;γ=γ,γc=γc))
end
#using Bessels
# Out:
# Gamma_ϵ (generic function with 1 method)

# %%
#### Create electronic Hamiltonian 
function block_h(ny,γ,γso)
    #γ::Float64,γso::ComplexF64,Bz::Float64,ny::Int)
    "Creates the building blocks for a general nx x ny square lattice
    
    Returns:
       H0 :: intra-cell (y direction) Hamiltonian block of size (ny*nσ)×(ny*nσ)
       T  :: inter-cell (x direction) hopping block of same size"
    dim = ny*nσ # We include the spin degree of freedom 
    ######
    H0 = zeros(ComplexF64,dim,dim)
    T  = zeros(ComplexF64,dim,dim)
    One_y = Diagonal(ones(ny))
    ######
    Ty = diagm(-1 =>  ones(ny-1))
    T0 = Ty⊗(-γ*σ_0 - 1im*γso*σ_x)
    H0 .= T0 + T0' #-Bz*kron(One_y, σ_z)
    ######
    T .= One_y⊗(-γ*σ_0 + γso*1im*σ_y)
    return H0, T
end

function hs(vm_i1x::Array{Float64,2},nx,ny,γ,γso,j_sd)
    "This function build the central hamiltonian wwith two band"
    #γ::Float64,γso::ComplexF64,Bz::Float64,nx::Int,ny::Int)
    dim = nx*ny*nσ #*2
    zero = zeros(ComplexF64,nx,nx)
    HC = zeros(ComplexF64,dim,dim)
    One_x = Diagonal(ones(nx))
    H0,T = block_h(ny,γ,γso)
    Tx = diagm( -1 =>  ones(nx-1))⊗T 
    HC = (One_x⊗H0) +  Tx + Tx'
    ### Local moments
    for i in range(1,nx) 
        zero[i,i] = 1.0
        HC += -j_sd*zero⊗(vm_i1x[i,1]*σ_x
                    +vm_i1x[i,2]*σ_y
                    +vm_i1x[i,3]*σ_z)
        zero[i,i] = 0.0
    end
    return HC
end
## Note que el rango en ks se puede mejorar de tal forma de que el punto
## inicial y final no se repitan 

# function heα(ϵα0,γ,nk,nσ)
#     dim_e = nk*nσ
#     dim_α = nα
#     heα_kα = zeros(ComplexF64, (dim_e,dim_α))
#     ks = 1:nk
#     ln = nk+1
#     #ks =LinRange(-pi,pi,nk) # range(-π, stop=π, length=nk+1)[1:end-1]#
#     heα_kα[1:2:end,1] .= - 2γ*cos.(ks*pi/ln) .+ ϵα0[1] 
#     heα_kα[2:2:end,1] .= - 2γ*cos.(ks*pi/ln) .+ ϵα0[1] 
    
#     heα_kα[1:2:end,2] .= - 2γ*cos.(ks*pi/ln) .+ ϵα0[2] 
#     heα_kα[2:2:end,2] .= - 2γ*cos.(ks*pi/ln) .+ ϵα0[2] 
#     #he_k = ϵα0*diagm(ones(dim_e))
#     return heα_kα#h_kα
# end

# function hseα(ns,γc,nk,nσ)
#     dim_e = nk*nσ
#     dim_s = ns*nσ
#     #ks = LinRange(-pi,pi,nk) #range(-π, stop=π, length=nk+1)[1:end-1]#
#     ks = 1:nk
#     ln = nk+1
#     hseα_ikα = zeros(ComplexF64, (dim_s,dim_e,dim_α) )
#     hseα_ikα[1,1:2:end,1] .= -γc*sin.(ks*pi/ln)*sqrt(2/ln)#*sqrt(1/pi)
#     hseα_ikα[2,2:2:end,1] .= -γc*sin.(ks*pi/ln)*sqrt(2/ln)#*sqrt(1/pi)

#     hseα_ikα[end-1,1:2:end,2] .= -γc*sin.(ks*pi/ln)*sqrt(2/ln)#*sqrt(1/pi)
#     hseα_ikα[end,2:2:end,2] .= -γc*sin.(ks*pi/ln)*sqrt(2/ln)#*sqrt(1/pi)
#     # hseα_ik[1,1] = 
#     # hseα_ik[1,1] = 
#     return hseα_ikα
# end
function fermi(ϵ)
    """ Fermi function 
    """
   #fermi = 1. / (1. + exp(ϵ))
    ϵ> 36 ? 0.0 : (ϵ < -36 ? 1.0 : 1.0/(1.0 + exp(ϵ)))
end
# Out:
# fermi (generic function with 1 method)

# %%
# ee=-20:0.1:20
# plt.plot(ee,fermi.(ee*100))

# %%
#### Flatting tensors and tensoring 
function to_matrix(vec)
    """Returns the tensor version of the flattened vector"""
    Gleαs_kαij = reshape(vec[1:size_Gleαs_kαij], dims_Gleαs_kαij )
    Gls_ij = reshape(vec[size_Gleαs_kαij+1:size_Gleαs_kαij+size_Gls_ij], dims_Gls_ij )
    return Gleαs_kαij, Gls_ij
end
#Gleαs_kαi, Gls_ij = to_matrix(dv.rkvec)
# Out:
# to_matrix (generic function with 1 method)

# %%
### Now we should calculate the poles and residues 
#### number of poles
#n = 50
function ozaki_poles(M::Int)
    @assert M ≥ 1
    M=2*M
    # Symmetric tridiagonal with off-diagonals b_n = 1 / (2*sqrt(4n^2 - 1))
    b = [1.0/(2*sqrt(4n^2 - 1.0)) for n in 1:M-1]
    T = SymTridiagonal(zeros(M), b)        # main diagonal zeros, off-diagonals b
    F = eigen(T)                            # F.values::Vector, F.vectors::Matrix
    λ = F.values
    V = F.vectors
    # keep positive eigenvalues
    pos = findall(>(0.0), λ)
    # println(pos)
    # println(λ[pos])
    ξ = 1 ./λ[pos]                       # poles (imag-axis locations)
    η = norm.(V[1, pos]).^2 ./ (4.0*λ[pos].^2)             # weights = (first component)^2
    #println(size(ξ))
    #println(size(η))
    return ξ, η
end
# Out:
# ozaki_poles (generic function with 1 method)

# %%
#1/0.8

# %%
# ε = range(-5, 5, 1001)
# f_approx = fermi_ozaki(ε; β=38, μ=μ, ξ=ξ, η=η)

# plt.plot(ε,f_approx.-1/2)
# using PyPlot
# es= -10:0.01:10
# ξ_k,η_k = ozaki_poles()
# f_rec(x) = 0.5- sum(η_k/β.*(1 ./( 1im*ξ_k/β .+ x ) .+  1 ./( -1im*ξ_k/β .+ x )   ))
# plt.plot(es,f_rec.(es))
# plt.plot(es,fermi.(es*38),ls = "--")
#f_rec(1)
#plt.ylim(-1,1)
#f_rec(0.0)
#f_rec.(es)

# %%
#η_k



#ξ_k 
# u(x) = (η_k/β).*1 ./( -1im*ξ_k/β .+ x) 
# u(3)

# %% [markdown]
# ## EOM

# %%
#stepp(t;ti=3,to=25) = 1/(1+exp(-(t-to)/ti))

# %%
### Equations of motion
function eom!(du,u,p,t)
    """This function defines the differential equation
    """
    #### Initiallize the vectors 
    dGleαs_kαij = Array{ComplexF64}(undef, dims_Gleαs_kαij   )
    #Gleαs_kαi = Array{ComplexF64}(undef, dims_Gleαs_kαi   )
    dGls_ij = Array{ComplexF64}(undef, dims_Gls_ij   )
    #### Transformation to matrix 
    p.Gleαs_kαij, p.Gls_ij = to_matrix(u)
    Gleαs_kαij = p.Gleαs_kαij
    Gls_ij = p.Gls_ij
    ### Updated Hamiltonians (In principle this hamiltonians can be updated in time )
    hs_ij =  p.hs_ij
    s_α = p.s_α
    Γ_αij = p.Γ_αij
    η_k = p.η_k  #### residues
    ξ_k = p.ξ_k
    ### Precalculated quantities 
    Γ_ij = zero(Gls_ij)
    @tullio Γ_ij[i,j] = Γ_αij[α,i,j]*s_α[α]^2
    #Γ = Γs*I_ab
    heff =  hs_ij - 1im*Γ_ij/2
    ###--------- Equations of motion -----------###
    # ### Green function of the system 
    @tullio dGleαs_kαij[k,α,i,j]  = 1im*s_α[α]*I_ab[i,j] 
    @tullio dGleαs_kαij[k,α,i,j]  += 1im*Gleαs_kαij[k,α,i,l]*conj(heff[j,l])   
    @tullio dGleαs_kαij[k,α,i,j]  += -Gleαs_kαij[k,α,i,j]*ξ_k[k]/β  
    du[1:size_Gleαs_kαij] .= vec(dGleαs_kαij)
    ### Mixed Green function 
    @tullio dGls_ij[i,j] = -1im*heff[i,l]*Gls_ij[l,j] 
    @tullio dGls_ij[i,j] += 1im*Γ_ij[i,j]/4 
    @tullio dGls_ij[i,j] += 1im*s_α[α]*η_k[k]*Γ_αij[α,i,l]*Gleαs_kαij[k,α,l,j]/β
    dGls_ij -= dGls_ij'
    #0.0#HC Hermitic conjugate 
    du[size_Gleαs_kαij+1:size_Gleαs_kαij+size_Gls_ij] .= vec(dGls_ij)
    nothing 
end

#dv.heαs_kαi
# Out:
# eom! (generic function with 1 method)

# %%
#dv.Gls_ij
#1/nk*10
#zeros(ComplexF64,(nα,dim_s,dim_s))

# %%
### Observables 
function Observables!(vec, ov, dv )
    """This function calculates the observables at each time step 
    """
    ### Observables 
    # hs_ij = dv.hs_ij
    # s_α = dv.s_α
    # Γ_α = dv.Γ_α
    # η_k = dv.η_k  #### residues
    # ξ_k = dv.ξ_k
    # ### Precalculated quantities 
    Γ_ij = zero(dv.Gls_ij)
    I = zeros(ComplexF64,(dim_α,dim_s,dim_s))#[α,i,j]
    @tullio Γ_ij[i,j] = dv.Γ_αij[α,i,j]*dv.s_α[α]^2
    ###heff =  dv.hs_ij - 1im*Γ_ij/2
    ### Charge current in the leads
    #
    @tullio I[α,i,j] = -1im*dv.s_α[α]^2*dv.Γ_αij[α,i,l]*dv.Gls_ij[l,j]/2
    @tullio I[α,i,j] += - dv.s_α[α]^2*dv.Γ_αij[α,i,j]/4
    @tullio I[α,i,j] += dv.s_α[α]*dv.η_k[k]*dv.Γ_αij[α,i,l]*dv.Gleαs_kαij[k,α,l,j]/β
    #@tullio ov.curr_α[α] =  real <| -conj(dv.hseα_ikα[i,k1,α]*dv.Gleαs_kαi[k1,α,i])#*1/nk#*2pi/nk #-2*conj(
    @tullio ov.curr_α[α] = real( 2*I[α,i,i])
    #@tullio ov.curr_α[α] = Γ_ij[i,j]*(-1im*dv.Gls_ij[j,i])/2
    # @tullio ov.curr_α[α] += - Γ_ij[j,j]/4
    # @tullio ov.curr_α[α] += s_α[α]*dv.η_k[k]*dv.Γ_α[α]*Gleαs_kαij[k,α,i,i]
    ### Spin current in the leads 
    @tullio ov.scurr_xα[x,α] = real( 4*pi*σ_ijx[l,j,x]*I[α,j,l] )
    #@tullio ov.scurr_xα[x,α] =  real <| -conj(4*pi*σ_ijx[l,j,x]*dv.hseα_ikα[j,k1,α]*dv.Gleαs_kαi[k1,α,l])#*1/nk#*2pi/nk 
    ### Spin density 
    @tullio ov.sden_xij[x,i,j] =  -1im*dv.Gls_ij[i,j1]*σ_ijx[j1,j,x]              
    @tullio ov.sden_i1x[i1,x] = real( ov.sden_xij[x,2i1-1,2i1-1] + ov.sden_xij[x,2i1,2i1] )
    @tullio ov.cden_i[i] = real( -1im*(dv.Gls_ij[i,i] ) )
    nothing 
end
# Out:
# Observables! (generic function with 1 method)

# %%
#σ_ijx

# %%
### Setting the strucures that stores the parameters and dynamical variables 
Base.@kwdef mutable struct observables_var
    """ This structure stores the observables that are calculates
    """
    sden_i1x::Array{ComplexF64,2}
    curr_α::Vector{ComplexF64}
    scurr_xα::Array{ComplexF64,2}
    sden_xij::Array{ComplexF64,3}
    cden_i::Array{ComplexF64}
end
####
Base.@kwdef mutable struct dynamics_var
    """ Variables that can be modified dynamically in the evolution
    """
    #println(1)
    #### Electronic hamiltonians 
    hs_ij::Array{ComplexF64,2} 
    #### Electron variables 
    Gleαs_kαij::Array{ComplexF64,4} 
    Gls_ij::Array{ComplexF64,2} 
    #gl_kα::Array{ComplexF64,2}
    rkvec::Array{ComplexF64,1}
    ### Classical spin 
    vm_i1x::Array{Float64,2}
    # Fermi decomposition 
    #s_α = p.s_α
    #Γ_α = p.Γ_α
    η_k::Array{ComplexF64,1}#  = p.η_k  #### residues
    ξ_k::Array{ComplexF64,1}#  = p.ξ_k
    s_α::Array{Float64,1}
    Γ_αij::Array{Float64,3}

    #ξ_k,η_k,s_α,Γ_α


        # dv = dynamics_var(hs_ij,
        # Gleαs_kαij,Gls_ij,rkvec,
        # vm_i1x,η_k,ξ_k,s_α,Γ_αij)
end
####
Base.@kwdef mutable struct llg_parameters
""" Parameters of the LLG evolution 
"""
    #n_sites::Int = n_sites
    nx::Int 
    ny::Int  
    nt::Int 
    dt::Float64 
    h0_a1x::Array{Float64,2} 
    jx_exc::Float64 
    jy_exc::Float64 
    g_lambda::Float64 
    j_sd::Float64 
    j_dmi::Float64
    j_ani::Float64 
    j_dem::Float64 
    js_pol::Float64 
    js_ana::Float64 
    thop::Float64
    ##### Local fields 
    e_x::Vector{Float64} 
    e_demag_x::Vector{Float64} 
    js_sd_a1::Vector{Float64} 
    js_ani_a1::Vector{Float64}  
    js_dem_a1::Vector{Float64}  
    ##### Non-local fields
    jxs_exc::Vector{Float64} 
    jys_exc::Vector{Float64}  
    ε::Array{Int,3}
end
# Out:
# llg_parameters

# %% [markdown]
# ## Initial conditions

# %%
#Gamma_ϵ(0.0;γ=γ,γc=γc)
# Γ_αij = zeros(Float64,(dim_α,dim_s,dim_s))
# typeof(Γ_αij)

# %%
### Function to set the initial condition of the structures 
function init_params()
    """Returns the structures with the initial parameters"""
    #### global parameters
    nx = 2
    ny = 1
    ns = nx*ny
    nσ = 2
    nα = 2
    nk = 20
    γ = 1
    γso = 0.0
    γc = 1.0#1.0#1.0#1.0
    ϵ0 = 0.0#2γ
    Temp = 300#300#0.01#300#0.1
    j_sd = 0.1
    
    #ks = LinRange(-pi,pi,nk) # range(-π, stop=π, length=nk+1)[1:end-1]#
    #ks = 1:nk
    #ln = nk+1
    vm_i1x = zeros(Float64,nx*ny,3)
    μ_α = [0.0,0.0]
    ϵ0α = [0.0,0.0] # [0.05,0.0]
    β = 1/(k_Boltzman*Temp ) # 2.4#
    size_rkvec = size_Gleαs_kαij+size_Gls_ij
    ###------------- Initial value of the classical spin-----#####
    theta_1, phi_1 = 20.0 , 0.0#45.0, 0.0 
    period = 5.0 
    pr_spins = [PrecSpin(i) for i in 1:1:2  ]        ### array with mutables object of preccesin spins
    for jj in 1: 2
    pr_spins[jj].i = jj ## lattice site 
    pr_spins[jj].theta_zero = theta_1 
    pr_spins[jj].phi_zero = phi_1 
    pr_spins[jj].T = period 
    end
    for j in 1:1:2 #3:1:5#n_precessing#length(pr_spins)
    update!(pr_spins[j], 0.0 )
    vm_i1x[pr_spins[j].i,:] .= pr_spins[j].s
    end   
    ####------------ Dynamical variables--------#########
    #### Electronic hamiltonians 
    hs_ij = hs(vm_i1x,nx,ny,γ,γso,j_sd)#::Array{ComplexF64,2} 
    #heαs_kαi = permutedims(hseα_ikα, (2,3,1))
    #### Electron variables 
    Gleαs_kαij = zeros(ComplexF64, dims_Gleαs_kαij  )
    Gls_ij = zeros(ComplexF64, dims_Gls_ij );
    Γ_αij = zeros(Float64,(dim_α,dim_s,dim_s))#zeros(Float64,2)
    s_α = zeros(Float64,dim_α)
    
    #Gls_ij[2:2:end,2:2:end] .= 1.0
    ε₂, U₂ = eigen(hs_ij)
    f₂ = fermi.((ε₂)*β)
    ### it is in termal equilibrium
    Gls_ij .= 1im *(U₂' * Diagonal(f₂) * U₂)
    ξ_k,η_k = ozaki_poles(dim_e)
    #ξ_k,η_k = ξ_k/β,η_k/β
    
    Γ0 = Gamma_ϵ(0.0;γ=γ,γc=γc*1.0)
    
    Γ_αij[1,1,1] =  Γ0#Gamma_ϵ(0.0;γ=γ,γc=γc)
    Γ_αij[1,2,2] =  Γ0
    
    Γ_αij[2,3,3] =  Γ0#Gamma_ϵ(0.0;γ=γ,γc=γc)
    Γ_αij[2,4,4] =  Γ0
    s_α[1] = stepp(0.0)
    s_α[2] = stepp(0.0)
    
    rkvec = zeros(ComplexF64, size_rkvec)
    rkvec[1:size_Gleαs_kαij] = vec(Gleαs_kαij)
    rkvec[size_Gleαs_kαij+1:size_Gleαs_kαij+size_Gls_ij] .= vec(Gls_ij)
    
    ### Classical spin 
    #println(0)
    dv = dynamics_var(hs_ij,
        Gleαs_kαij,Gls_ij,rkvec,
        vm_i1x,η_k,ξ_k,s_α,Γ_αij)
    #println(0)
    #####----------- Observable variables --------------##########
    sden_i1x= zeros(Float64, ns, 3)#::Array{Float64,2}
    curr_α= zeros(Float64, nα)#::Vector{Float64}
    scurr_xα = zeros(Float64, 3, nα)#::Array{Float64,2}
    sden_xij = zeros(ComplexF64, 3, nσ*ns, nσ*ns)#::Array{ComplexF64,3}
    cden_i = zeros(ComplexF64, ns*nσ)
    @tullio cden_i[i] = real( -1im*(dv.Gls_ij[i,i] ) )
    ov = observables_var(sden_i1x,
        curr_α, scurr_xα, sden_xij,cden_i)
    #####----------- LLG parameters--------------########## 
    nx = nx
    ny = ny
    nt = 1
    dt = 0.1
    h0_a1x = zeros(Float64, nx * ny, 3)
    jx_exc   = 0.0#fill(jx_exc, nx - 1)      #  nn exchange along x bonds
    jy_exc   = 0.0#fill(jy_exc, ny - 1)      #  nn exchange along y bonds
    g_lambda = 0.0
    j_sd = 0.0
    j_dmi = 0.0
    j_ani = 0.0
    j_dem = 0.0
    js_pol = 0.0
    js_ana = 0.0
    thop = 0.0 ####
    e_x = [0.0,0.0,0.0]    
    e_demag_x = [0.0, 0.0, 0.0]
    js_sd_a1  = fill(j_sd,  nx * ny)      #  layer-1 on-site sd coupling
    js_ani_a1 = fill(j_ani, nx * ny)      #  layer-1 anisotropy
    js_dem_a1 = fill(j_dem, nx * ny)      #  layer-1 demag
    # Non-local exchange couplings in x and y directions
    jxs_exc = fill(jx_exc, nx - 1)
    jys_exc = fill(jy_exc, ny - 1)
    ε = zeros(Int, 3, 3, 3)
    ε[1,2,3] = ε[2,3,1] = ε[3,1,2] = 1
    ε[3,2,1] = ε[2,1,3] = ε[1,3,2] = -1    
    #println(0)
    lv = llg_parameters(
    nx, ny, nt, dt, h0_a1x,
    jx_exc, jy_exc, g_lambda,
    j_sd, j_dmi, j_ani, j_dem,
    js_pol, js_ana, thop, e_x, e_demag_x,
    js_sd_a1, js_ani_a1, js_dem_a1,
    jxs_exc, jys_exc, ε)
    return dv,ov,lv
end
#dv, ov, lv = init_params();

# %%
#-im*tr(dv.Gls_ij[1:2,1:2]*σ_z)
#inv(I(4)+exp(hs_ij*0.1))
#dim_s
#Gamma_ϵ(0.0;γ=γ*10,γc=γc*0.1)

# %%
#dv.Gls_ij
#dv.hs_ij
#Gls_ij[2:2:end,2:2:end] .= 1.0
#sum(dv.gl_kα[:,2])*1/nk
#-im*dv.Gls_ij

# dv.hs_ij

# ε₂, U₂ = eigen(dv.hs_ij)

#inv(dv.hs_ij)
#1/(KB*300)

# %%
# U₂[:,2]'*dv.hs_ij*U₂[:,2]


# transpose(U₂)

# %%
# #Gls_ij
# ks = LinRange(-pi,pi,nk) 
# Temp = 300
# ϵ_k = -2γ*cos.(ks) #.+ 2γ#ϵ0
# μ_α = [0.0,0.0]
# ϵ0α = [0.0,0.0]
# β = 1/(k_Boltzman*Temp )
# sum(1im*fermi.((ϵ_k.+μ_α[1])*β))/nk

# %%
### LLG dynamics 
function heff(vm_a1x,vs_a1x,lp )
    """ Computes the effective hamiltonian 
    of the LLG equations
    """
    #MBOHR = 5.788381e-5         ### Bohrs magneton
    one_x = Matrix{Float64}(I, lp.nx, lp.nx)
    one_y = Matrix{Float64}(I, lp.ny, lp.ny) ;
    ####Auxiliary tensors
    J_exc_a1a2 = diagm(-1 => lp.jxs_exc , 1=> lp.jxs_exc )⊗one_y +  one_x⊗diagm(-1 => lp.jys_exc , 1=> lp.jys_exc ) 
    #### All the parameters are imported from the llg_params mutable structure 
    hef_a1x = zeros(Float64,lp.nx*lp.ny,3)
    #### Note that the sum should be splitted because each index summed factorize the expression
    @tullio  hef_a1x[a2,x] = J_exc_a1a2[a1,a2]*vm_a1x[a1,x]/MBOHR
    # @tullio  hef_a1x[a2,x] += lp.js_sd_a1[a2]*vs_a1x[2a2-1,x]/MBOHR ### Coupling to conduction band
    @tullio  hef_a1x[a2,x] += lp.js_sd_a1[a2]*vs_a1x[a2,x]/MBOHR ### Coupling to valence band
    @tullio  hef_a1x[a2,x] += lp.js_ani_a1[a2]*vm_a1x[a2,x1]*lp.e_x[x1]*lp.e_x[x]/MBOHR
    @tullio  hef_a1x[a2,x] += -lp.js_dem_a1[a2]*vm_a1x[a2,x1]*lp.e_demag_x[x1]*lp.e_demag_x[x]/MBOHR
    @tullio  hef_a1x[a2,x] += lp.h0_a1x[a2,x]
end
### Evolution using Heun's method
function corrector(vm_a1x,vs_a1x,lp)
    """This function calculates the correction associated to the 
    evolution in the heun propagation
    """
    GAMMA_R = 1.760859644e-4    ### Gyromagnetic ratio ##1 for units of G_r=1
    hef_a1x = heff(vm_a1x,vs_a1x, lp )
    @tullio sh_a1x[a,x] := vm_a1x[a, i] * hef_a1x[a, j] * lp.ε[i,j,x] #(i in 1:3, j in 1:3)
    @tullio shh_a1x[a,x] := vm_a1x[a,i] * sh_a1x[a,j] * lp.ε[i,j,x]
    del_m = (-GAMMA_R/(1. + lp.g_lambda^2) )*(sh_a1x + lp.g_lambda*shh_a1x)
    return del_m
end
function heun(vm_a1x,vs_a1x, dt::Float64, lp ) 
    """ This function propagates the vector vm_a1x in a time step dt
    using heuns method (RK2)
    """
    vm_a1x = Array(hcat(normalize.(eachrow(vm_a1x))...)')
    del_m = corrector(vm_a1x,vs_a1x,lp)
    vm_a1x_prime = vm_a1x + del_m*dt
    vm_a1x_prime = Array(hcat(normalize.(eachrow(vm_a1x_prime))...)')
    del_m_prime = corrector(vm_a1x_prime,vs_a1x , lp)
    vm_a1x = vm_a1x + 0.5*(del_m + del_m_prime )*dt
    vm_a1x = Array(hcat(normalize.(eachrow(vm_a1x))...)')
end
# Out:
# heun (generic function with 1 method)

# %% [markdown]
# #### Precesion

# %%
mutable struct PrecSpin
    """ This mutable structure act like a class 
    in python, it defines an object with the 
    characteristics of a precessing spin
    """
    i::Int64 #   
    axis_phi::Float64 
    axis_theta::Float64 
    phi_zero::Float64 
    theta_zero::Float64 
    start_time::Float64 
    T::Float64 
    s::Vector{Float64} 
    ### Initial values of PrecSpin .
    function PrecSpin(i=0,axis_phi=0.0,axis_theta=0.0,
            phi_zero=0.0,theta_zero=0.0,start_time=0.0
            ,T=1.,s=[0.,0.,1.])
        new(i,axis_phi,axis_theta,phi_zero,theta_zero,start_time,T,s)
    end
end

function update!(this::PrecSpin, time  )
    """ This function  update the magnetic moment associated
    to the mutable structure PrecSpin 
    
    parameters:
    ----------
    this: mutable structure 
    contain an structure with the characteristics of a spin 
    time: Float64
    time where the spin is evaluated 
    
    returns:
    -------
    Update the strucure associated to a  precessing spin 
    """
    if time >= this.start_time
        t = time - this.start_time
    else
        t = 0.0
    end
    omega = 2*pi / this.T
    otheta = pi* this.theta_zero/180.
    ophi = pi*this.phi_zero /180. ##########
    # compute spin position for precession along the z-axis
    sz = cos(otheta)
    sx = cos(ophi + omega*t)*sin(otheta)
    sy = sin(ophi + omega*t)*sin(otheta)
    # Now rotate along y 
    atheta = pi * this.axis_theta/ 180.
    aphi = pi * this.axis_phi / 180. 
    sx1 =  sx*cos(atheta) - sz*sin(atheta)
    sy1 =  sy
    sz1 =  sx*sin(atheta) + sz*cos(atheta)
    # No rotate along the z 
    sx2 =  sx1*cos(aphi) + sy1*sin(aphi)
    sy2 = -sx1*sin(aphi) + sy1*cos(aphi)
    sz2 =  sz1
    this.s .= [sx2, sy2, sz2]
    nothing
end
# # compute spin position for precession along the z-axis
# sz = cos(otheta)
# sx = cos(ophi+ omega*t)*sin(otheta)
# sy = sin(ophi+ omega*t)*sin(otheta)
# # Now rotate along y 
# atheta = pi * this.axis_theta/ 180.
# aphi = pi * this.axis_phi / 180. 
# sx = sx*cos(atheta) - sz* sin(atheta)
# sz = sx* sin(atheta) + sz*cos(atheta)
# # No rotate along the z 
# sx = sx*cos(aphi) + sy*sin(aphi)
# sy = -sx*sin(aphi) + sy*cos(aphi)
# this.s .= [sx, sy, sz]
# Out:
# update! (generic function with 1 method)

# %%
# theta_1, phi_1 = 15.0 , 0.0#45.0, 0.0 
# period = 10 
# pr_spins = [PrecSpin(i) for i in 1:1:n  ]        ### array with mutables object of preccesin spins
# for jj in 1: n
#     pr_spins[jj].i = jj ## lattice site 
#     pr_spins[jj].theta_zero = theta_1
#     pr_spins[jj].axis_phi = phi_1
#     pr_spins[jj].T = period 
#     #println(pr_spins[jj].i)
# end
# j_sd = 0.1
# ### Set the initial hamiltonian with the precessing spins 
# for j in 1:1:2#n #3:1:5#n_precessing#length(pr_spins)
#     #println(j)
#     #dv.vm_i1x[2,:] .= zeros(Float64,3)
#     update!(pr_spins[j], 0.0 )
#     dv.vm_i1x[pr_spins[j].i,:] .= pr_spins[j].s
# end

# %%
#n1/pi

# %%
1/pi
# Out:
# 0.3183098861837907

# %% [markdown]
# ## Evolution

# %%
### Evolution of the dynamics 
t_0 = 0.0
t_step = 0.1
t_end = 60#120#120#50#250#100
name = "test6"
function main()
    ##### Initial conditions 
    dv, ov, lv = init_params()
    n = nx*ny
    dv.vm_i1x = zeros(Float64,nx*ny,3)
    pr_spins = [PrecSpin(i) for i in 1:1:nx  ]        ### array with mutables object of preccesin spins
    #vm_i1x[:,3] .= 1.0
    #dv.vm_i1x = [zeros(Float64,3) for _ in 1:n]
    ### Initiallizing the precessing classical moments to study the pumping dynamics 
    theta_1, phi_1 = 20.0 , 0.0#45.0, 0.0 
    period = 5 
    pr_spins = [PrecSpin(i) for i in 1:1:2  ]        ### array with mutables object of preccesin spins
    for jj in 1: 2
        pr_spins[jj].i = jj ## lattice site 
        pr_spins[jj].theta_zero = theta_1
        pr_spins[jj].phi_zero = phi_1
        pr_spins[jj].T = period 
        #println(pr_spins[jj].i)
    end
    j_sd = 0.1
    ## Set the initial hamiltonian with the precessing spins 
    for j in 1:1:2 #3:1:5#n_precessing#length(pr_spins)
        update!(pr_spins[j], 0.0 )
        dv.vm_i1x[pr_spins[j].i,:] .= pr_spins[j].s
    end   
    #dv.hs_ij = hs(dv.vm_i1x,nx,ny,γ,γso,j_sd) 
    #stepp(t;ti=40) = t < ti ? sin((pi/2)*t/ti)^2 : 1
    stepp(t;ti=3,to=25) = 1/(1+exp(-(t-to)/ti))
    
    dv.hs_ij = hs(dv.vm_i1x,nx,ny,γ,γso,j_sd) #j_sd

    println("Initial condition")
    ##### Setting the differential equation 
    prob = ODEProblem(eom!,dv.rkvec, (t_0,t_end), dv) #Vern7()
    integrator =  init(prob,RK4(),dt = t_step, save_everystep=false,adaptive=true,dense=false)
    ##### Opening files to save the data
    cc_f = open("./data/cc_$(name)_jl.txt", "w+") 
    sneq_f = open("./data/sneq_$(name)_jl.txt", "w+")
    sc_f = open("./data/sc_$(name)_jl.txt", "w+") 
    cspins_f = open("./data/cspins_$(name)_jl.txt", "w+") 
    cden_f = open("./data/cden_$(name)_jl.txt", "w+") 
    rho_f = open("./data/rho_$(name)_jl.txt", "w+") 
    ##### Setting the iterative evolution 
    println(dv.vm_i1x)
    println("Starting time evolution")
    elapsed_time = @elapsed begin
        for (i,t) in enumerate(t_0:t_step:t_end-t_step)
            tt = round((i)*t_step,digits=2)
            println("time: ", tt  )
            ### asure that time_step is printed
            flush(stdout)         
            ### evolve one time step 
            step!(integrator,t_step, true)   
            #dv.Gleαs_kαij,dv.Gls_ij = to_matrix(integrator.u)
            ### evaluation of observables 
            Observables!(integrator.u,ov,dv)
            ### evolution of classical dynamics 
            #dv.vm_i1x .= heun(dv.vm_i1x,ov.sden_i1x,t_step,lv)
            ### Update parameters
            ####-----------------------Leviton-----------------------####
            # t0 = 100
            # τ = 7 
            # dv.heα_kα[1:2:end,1] .= lev(t;t0,τ)
            # dv.heα_kα[2:2:end,1] .= lev(t;t0,τ)
            ####----------------------Gaussian Pulse-----------------####
            # t0 = 50
            # τ = 1
            # A = 0.5
            # dv.heα_kα[1:2:end,1] .= gauss(t;A,t0,τ)#A*exp(-(t-t0)^2/(2*τ^2))
            # dv.heα_kα[2:2:end,1] .= gauss(t;A,t0,τ)#A*exp(-(t-t0)^2/(2*τ^2))
            ####----------------------Precesion-----------------------####
                #dv.hs_ij = hs(dv.vm_i1x,nx,ny,γ,γso,0.0) #j_sd
            #if tt>=80 
            for j in 1:1:2 #3:1:5#n_precessing#length(pr_spins)
                #println(j)
                pr_spins[j].i = j ## lattice site 
                pr_spins[j].theta_zero = theta_1
                pr_spins[j].phi_zero = phi_1
                pr_spins[j].T = period 
                #dv.vm_i1x[2,:] .= zeros(Float64,3)
                update!(pr_spins[j], tt )
                dv.vm_i1x[pr_spins[j].i,:] .= pr_spins[j].s
            end   
            #end
            ### update hamiltonian 
            #integrator.p.hs_ij = hs(dv.vm_i1x,nx,ny,γ,γso,j_sd) 
            dv.hs_ij = hs(dv.vm_i1x,nx,ny,γ,γso,j_sd)#j_sd*stepp1(t;ti=80)) 
            dv.s_α .= stepp(t)
            #@tullio heαs_kαi[k,α,i] := dv.hseα_ikα[i,k,α]
            #hseα_ikα[i,k,α]
            #dv.heαs_kαi = heαs_kαi##*stepp(t)
            #println(dv.vm_i1x)
            #dv.heαs_kαi[1,1,1] = 0.5*exp(-(t-tγ)^2/(2*τ^2))
            #hs(dv.vm_a1x,p)
            #println(sum(dv.gl_kα[:,1])/nk )
            # ρs = -im .* dv.Gls_ij
            # ρe_diag = -im .* diag.(eachslice(dv.Gleα_qkα; dims=1))  # o extrae Gleα_qkα[k,k,α]
            # Ntot = tr(ρs) + sum(ρe_diag)  # constante (a tolerancia)
            # println(Ntot)
            println(-1im*dv.Gls_ij[1,1])
            # println(ov.scurr_xα)
            #println(-1im*(dv.Gls_ij[1,1]+dv.Gls_ij[2,2]))
            #println(-1im*(dv.Gls_ij[3,3]+dv.Gls_ij[4,4]))
            ### save the data 
            #println(real(ov.sden_i1x))
            writedlm(rho_f, transpose(vec(dv.Gls_ij)) , ',' )
            writedlm(cc_f, real(ov.curr_α), ' ' )
            writedlm(sneq_f, real(ov.sden_i1x), ' ' )
            writedlm(sc_f, real(ov.scurr_xα ), ' ' )
            writedlm(cspins_f,real(dv.vm_i1x), ' ' )
            writedlm(cden_f, real(ov.cden_i), ' ' )
            #### After 1 evolution step we modify the hamiltonian of the lead 
            #### in order to get an initial zero current 
            # heα_kα = heα([0.05,0.0],γ,nk,nσ)#::Array{ComplexF64,2} 
            # @tullio heαs_kαi[k,α,i] := hseα_ikα[i,k,α]#::Array{ComplexF64,3} 
            # dv.heα_kα = heα_kα
            # dv.heαs_kαi = heαs_kαi
            # integrator.p.heα_kα = heα_kα
            # integrator.p.heαs_kαi = heαs_kαi
        end
    end
    close(rho_f)
    close(cc_f)
    close(cden_f)
    close(sneq_f)
    close(sc_f)
    close(cspins_f )
    println("Total time of simulation: ", elapsed_time, " s" )
    nothing 
end
# Out:
# main (generic function with 1 method)

# %%
#2>=1

# %%
main()
# Out:
# Initial condition
# [0.3420201433256687 0.0 0.9396926207859084; 0.3420201433256687 0.0 0.9396926207859084]
# Starting time evolution
# time: 0.1
# 0.5000000000167072 + 0.0im
# time: 0.2
# 0.5000000000646843 + 0.0im
# time: 0.3
# 0.5000000001555878 + 0.0im
# time: 0.4
# 0.5000000002810175 + 0.0im
# time: 0.5
# 0.5000000004515466 + 0.0im
# time: 0.6
# 0.5000000006663714 + 0.0im
# time: 0.7
# 0.5000000009293766 + 0.0im
# time: 0.8
# 0.5000000012410818 + 0.0im
# time: 0.9
# 0.5000000016047014 + 0.0im
# time: 1.0
# 0.5000000020199782 + 0.0im
# time: 1.1
# 0.5000000024894686 + 0.0im
# time: 1.2
# 0.5000000030121753 + 0.0im
# time: 1.3
# 0.5000000035896934 + 0.0im
# time: 1.4
# 0.5000000042203124 + 0.0im
# time: 1.5
# 0.5000000049044675 + 0.0im
# time: 1.6
# 0.5000000056397373 + 0.0im
# time: 1.7
# 0.500000006425304 + 0.0im
# time: 1.8
# 0.5000000072580297 + 0.0im
# time: 1.9
# 0.5000000081358525 + 0.0im
# time: 2.0
# 0.5000000090549297 + 0.0im
# time: 2.1
# 0.5000000100120585 + 0.0im
# time: 2.2
# 0.5000000110027455 + 0.0im
# time: 2.3
# 0.5000000120228341 + 0.0im
# time: 2.4
# 0.5000000130672975 + 0.0im
# time: 2.5
# 0.5000000141312861 + 0.0im
# time: 2.6
# 0.5000000152094365 + 0.0im
# time: 2.7
# 0.5000000162965277 + 0.0im
# time: 2.8
# 0.5000000173871348 + 0.0im
# time: 2.9
# 0.5000000184760435 + 0.0im
# time: 3.0
# 0.5000000195581175 + 0.0im
# time: 3.1
# 0.5000000206285732 + 0.0im
# time: 3.2
# 0.5000000216829742 + 0.0im
# time: 3.3
# 0.5000000227174294 + 0.0im
# time: 3.4
# 0.5000000237286572 + 0.0im
# time: 3.5
# 0.500000024714145 + 0.0im
# time: 3.6
# 0.5000000256722473 + 0.0im
# time: 3.7
# 0.5000000266023262 + 0.0im
# time: 3.8
# 0.5000000275048602 + 0.0im
# time: 3.9
# 0.5000000283815718 + 0.0im
# time: 4.0
# 0.5000000292355394 + 0.0im
# time: 4.1
# 0.5000000300713108 + 0.0im
# time: 4.2
# 0.5000000308950069 + 0.0im
# time: 4.3
# 0.5000000317144218 + 0.0im
# time: 4.4
# 0.5000000325391133 + 0.0im
# time: 4.5
# 0.5000000333804857 + 0.0im
# time: 4.6
# 0.5000000342518632 + 0.0im
# time: 4.7
# 0.5000000351685499 + 0.0im
# time: 4.8
# 0.5000000361478846 + 0.0im
# time: 4.9
# 0.5000000372092767 + 0.0im
# time: 5.0
# 0.5000000383742365 + 0.0im
# time: 5.1
# 0.5000000396663858 + 0.0im
# time: 5.2
# 0.5000000411114615 + 0.0im
# time: 5.3
# 0.5000000427372999 + 0.0im
# time: 5.4
# 0.5000000445738089 + 0.0im
# time: 5.5
# 0.5000000466529276 + 0.0im
# time: 5.6
# 0.5000000490085716 + 0.0im
# time: 5.7
# 0.5000000516765628 + 0.0im
# time: 5.8
# 0.5000000546945484 + 0.0im
# time: 5.9
# 0.5000000581019068 + 0.0im
# time: 6.0
# 0.5000000619396426 + 0.0im
# time: 6.1
# 0.5000000662502716 + 0.0im
# time: 6.2
# 0.5000000710776984 + 0.0im
# time: 6.3
# 0.5000000764670888 + 0.0im
# time: 6.4
# 0.5000000824647349 + 0.0im
# time: 6.5
# 0.5000000891179244 + 0.0im
# time: 6.6
# 0.5000000964748056 + 0.0im
# time: 6.7
# 0.500000104584265 + 0.0im
# time: 6.8
# 0.5000001139894735 + 0.0im
# time: 6.9
# 0.5000001234779059 + 0.0im
# time: 7.0
# 0.5000001342757331 + 0.0im
# time: 7.1
# 0.5000001458410495 + 0.0im
# time: 7.2
# 0.500000158628733 + 0.0im
# time: 7.3
# 0.5000001721388656 + 0.0im
# time: 7.4
# 0.5000001872420112 + 0.0im
# time: 7.5
# 0.5000002028022085 + 0.0im
# time: 7.6
# 0.5000002205404901 + 0.0im
# time: 7.7
# 0.5000002383542775 + 0.0im
# time: 7.8
# 0.5000002588723049 + 0.0im
# time: 7.9
# 0.5000002792229079 + 0.0im
# time: 8.0
# 0.5000003026892818 + 0.0im
# time: 8.1
# 0.5000003258362915 + 0.0im
# time: 8.2
# 0.5000003524703687 + 0.0im
# time: 8.3
# 0.5000003786606745 + 0.0im
# time: 8.4
# 0.5000004087206846 + 0.0im
# time: 8.5
# 0.5000004382173012 + 0.0im
# time: 8.6
# 0.5000004719949078 + 0.0im
# time: 8.7
# 0.500000505094545 + 0.0im
# time: 8.8
# 0.5000005429251501 + 0.0im
# time: 8.9
# 0.5000005799713393 + 0.0im
# time: 9.0
# 0.5000006222491838 + 0.0im
# time: 9.1
# 0.5000006636473506 + 0.0im
# time: 9.2
# 0.5000007106325074 + 0.0im
# time: 9.3
# 0.5000007574900106 + 0.0im
# time: 9.4
# 0.500000809302323 + 0.0im
# time: 9.5
# 0.5000008620401688 + 0.0im
# time: 9.6
# 0.5000009195562843 + 0.0im
# time: 9.7
# 0.5000009789502914 + 0.0im
# time: 9.8
# 0.5000010430008346 + 0.0im
# time: 9.9
# 0.5000011098897333 + 0.0im
# time: 10.0
# 0.5000011814727915 + 0.0im
# time: 10.1
# 0.5000012568361722 + 0.0im
# time: 10.2
# 0.5000013371978411 + 0.0im
# time: 10.3
# 0.5000014239213393 + 0.0im
# time: 10.4
# 0.5000015111484909 + 0.0im
# time: 10.5
# 0.500001612317438 + 0.0im
# time: 10.6
# 0.5000017093852495 + 0.0im
# time: 10.7
# 0.5000018232137952 + 0.0im
# time: 10.8
# 0.5000019404279954 + 0.0im
# time: 10.9
# 0.5000020600063675 + 0.0im
# time: 11.0
# 0.5000021946450555 + 0.0im
# time: 11.1
# 0.5000023339834677 + 0.0im
# time: 11.2
# 0.5000024920246259 + 0.0im
# time: 11.3
# 0.500002652023309 + 0.0im
# time: 11.4
# 0.5000028228888136 + 0.0im
# time: 11.5
# 0.5000030105166069 + 0.0im
# time: 11.6
# 0.5000032064247348 + 0.0im
# time: 11.7
# 0.5000034216481097 + 0.0im
# time: 11.8
# 0.5000036465593236 + 0.0im
# time: 11.9
# 0.5000038932222366 + 0.0im
# time: 12.0
# 0.5000041519922765 + 0.0im
# time: 12.1
# 0.5000044345036746 + 0.0im
# time: 12.2
# 0.500004732484155 + 0.0im
# time: 12.3
# 0.5000050560026029 + 0.0im
# time: 12.4
# 0.5000053990213819 + 0.0im
# time: 12.5
# 0.5000057654532334 + 0.0im
# time: 12.6
# 0.5000061626129635 + 0.0im
# time: 12.7
# 0.500006584861088 + 0.0im
# time: 12.8
# 0.500007039031756 + 0.0im
# time: 12.9
# 0.5000075239491881 + 0.0im
# time: 13.0
# 0.5000080437574496 + 0.0im
# time: 13.1
# 0.5000085994542103 + 0.0im
# time: 13.2
# 0.5000091941813241 + 0.0im
# time: 13.3
# 0.5000098300013556 + 0.0im
# time: 13.4
# 0.5000105098452149 + 0.0im
# time: 13.5
# 0.5000112726300255 + 0.0im
# time: 13.6
# 0.5000120298016689 + 0.0im
# time: 13.7
# 0.5000128639704556 + 0.0im
# time: 13.8
# 0.5000137469726348 + 0.0im
# time: 13.9
# 0.500014697553829 + 0.0im
# time: 14.0
# 0.5000157044330855 + 0.0im
# time: 14.1
# 0.5000167857313982 + 0.0im
# time: 14.2
# 0.5000179327580748 + 0.0im
# time: 14.3
# 0.5000191496765319 + 0.0im
# time: 14.4
# 0.5000204636435189 + 0.0im
# time: 14.5
# 0.5000218518042159 + 0.0im
# time: 14.6
# 0.5000233399768295 + 0.0im
# time: 14.7
# 0.5000249194798071 + 0.0im
# time: 14.8
# 0.5000266063059597 + 0.0im
# time: 14.9
# 0.5000284001741547 + 0.0im
# time: 15.0
# 0.500030312389422 + 0.0im
# time: 15.1
# 0.5000323473137553 + 0.0im
# time: 15.2
# 0.5000345145388395 + 0.0im
# time: 15.3
# 0.5000368211020598 + 0.0im
# time: 15.4
# 0.5000392764615921 + 0.0im
# time: 15.5
# 0.5000418894471163 + 0.0im
# time: 15.6
# 0.500044670180652 + 0.0im
# time: 15.7
# 0.5000476289752184 + 0.0im
# time: 15.8
# 0.5000507770440483 + 0.0im
# time: 15.9
# 0.5000541261437851 + 0.0im
# time: 16.0
# 0.5000576888351904 + 0.0im
# time: 16.1
# 0.5000614784094144 + 0.0im
# time: 16.2
# 0.500065508983273 + 0.0im
# time: 16.3
# 0.5000697955139584 + 0.0im
# time: 16.4
# 0.5000743538614828 + 0.0im
# time: 16.5
# 0.5000794770746658 + 0.0im
# time: 16.6
# 0.5000844104557685 + 0.0im
# time: 16.7
# 0.500090096761815 + 0.0im
# time: 16.8
# 0.500095823643473 + 0.0im
# time: 16.9
# 0.5001020754525021 + 0.0im
# time: 17.0
# 0.5001086292122054 + 0.0im
# time: 17.1
# 0.5001156069084481 + 0.0im
# time: 17.2
# 0.5001230628505858 + 0.0im
# time: 17.3
# 0.500130953700177 + 0.0im
# time: 17.4
# 0.5001393575478841 + 0.0im
# time: 17.5
# 0.5001482637101866 + 0.0im
# time: 17.6
# 0.5001577351406723 + 0.0im
# time: 17.7
# 0.5001677763670134 + 0.0im
# time: 17.8
# 0.5001784438162692 + 0.0im
# time: 17.9
# 0.5001897539376204 + 0.0im
# time: 18.0
# 0.5002017588283546 + 0.0im
# time: 18.1
# 0.5002144849854375 + 0.0im
# time: 18.2
# 0.5002279823972232 + 0.0im
# time: 18.3
# 0.5002422858357859 + 0.0im
# time: 18.4
# 0.5002574451355416 + 0.0im
# time: 18.5
# 0.5002735018968977 + 0.0im
# time: 18.6
# 0.5002905073098309 + 0.0im
# time: 18.7
# 0.5003085087638717 + 0.0im
# time: 18.8
# 0.5003275598708777 + 0.0im
# time: 18.9
# 0.5003477130884771 + 0.0im
# time: 19.0
# 0.500369025133538 + 0.0im
# time: 19.1
# 0.5003915530425684 + 0.0im
# time: 19.2
# 0.500415357020474 + 0.0im
# time: 19.3
# 0.5004404983785995 + 0.0im
# time: 19.4
# 0.5004670409214503 + 0.0im
# time: 19.5
# 0.5004950499303797 + 0.0im
# time: 19.6
# 0.500524592779733 + 0.0im
# time: 19.7
# 0.5005557384121536 + 0.0im
# time: 19.8
# 0.5005885575629664 + 0.0im
# time: 19.9
# 0.5006231224578674 + 0.0im
# time: 20.0
# 0.5006595068341193 + 0.0im
# time: 20.1
# 0.5006977857216499 + 0.0im
# time: 20.2
# 0.5007380353452542 + 0.0im
# time: 20.3
# 0.5007803329300623 + 0.0im
# time: 20.4
# 0.5008247565141065 + 0.0im
# time: 20.5
# 0.5008736669605406 + 0.0im
# time: 20.6
# 0.5009211298805942 + 0.0im
# time: 20.7
# 0.5009733765167926 + 0.0im
# time: 20.8
# 0.5010267973679824 + 0.0im
# time: 20.9
# 0.5010831222629593 + 0.0im
# time: 21.0
# 0.5011420257175524 + 0.0im
# time: 21.1
# 0.5012036068686309 + 0.0im
# time: 21.2
# 0.5012679495925142 + 0.0im
# time: 21.3
# 0.5013351114801323 + 0.0im
# time: 21.4
# 0.5014051740266234 + 0.0im
# time: 21.5
# 0.5014781975229358 + 0.0im
# time: 21.6
# 0.5015542531433294 + 0.0im
# time: 21.7
# 0.5016333979431928 + 0.0im
# time: 21.8
# 0.5017156928605953 + 0.0im
# time: 21.9
# 0.5018011884301481 + 0.0im
# time: 22.0
# 0.5018899346551329 + 0.0im
# time: 22.1
# 0.5019819728172845 + 0.0im
# time: 22.2
# 0.5020773407844175 + 0.0im
# time: 22.3
# 0.5021760682666299 + 0.0im
# time: 22.4
# 0.5022781795620862 + 0.0im
# time: 22.5
# 0.5023836907807818 + 0.0im
# time: 22.6
# 0.5024926112106293 + 0.0im
# time: 22.7
# 0.5026049416376972 + 0.0im
# time: 22.8
# 0.5027206750066694 + 0.0im
# time: 22.9
# 0.5028397953772294 + 0.0im
# time: 23.0
# 0.5029622907168245 + 0.0im
# time: 23.1
# 0.5030881174375674 + 0.0im
# time: 23.2
# 0.503217232481089 + 0.0im
# time: 23.3
# 0.5033495839712424 + 0.0im
# time: 23.4
# 0.503485110813373 + 0.0im
# time: 23.5
# 0.5036237427123712 + 0.0im
# time: 23.6
# 0.5037654002572524 + 0.0im
# time: 23.7
# 0.5039099951109085 + 0.0im
# time: 23.8
# 0.5040574302286204 + 0.0im
# time: 23.9
# 0.5042076001736733 + 0.0im
# time: 24.0
# 0.5043603914782017 + 0.0im
# time: 24.1
# 0.504515683006228 + 0.0im
# time: 24.2
# 0.5046733465388468 + 0.0im
# time: 24.3
# 0.5048332471876716 + 0.0im
# time: 24.4
# 0.5049952439660389 + 0.0im
# time: 24.5
# 0.5051591904050832 + 0.0im
# time: 24.6
# 0.5053249351886314 + 0.0im
# time: 24.7
# 0.5054923227728334 + 0.0im
# time: 24.8
# 0.505661194045219 + 0.0im
# time: 24.9
# 0.5058313869135409 + 0.0im
# time: 25.0
# 0.5060027370918874 + 0.0im
# time: 25.1
# 0.5061750785639795 + 0.0im
# time: 25.2
# 0.506348244431992 + 0.0im
# time: 25.3
# 0.5065220671954799 + 0.0im
# time: 25.4
# 0.5066963794908559 + 0.0im
# time: 25.5
# 0.5068710146002695 + 0.0im
# time: 25.6
# 0.5070458069719326 + 0.0im
# time: 25.7
# 0.507220592487705 + 0.0im
# time: 25.8
# 0.5073951865825149 + 0.0im
# time: 25.9
# 0.5075694249988116 + 0.0im
# time: 26.0
# 0.5077432058865102 + 0.0im
# time: 26.1
# 0.5079163262479285 + 0.0im
# time: 26.2
# 0.5080886862731474 + 0.0im
# time: 26.3
# 0.5082526017761723 + 0.0im
# time: 26.4
# 0.5084253123739081 + 0.0im
# time: 26.5
# 0.5085932762369829 + 0.0im
# time: 26.6
# 0.5087616656043528 + 0.0im
# time: 26.7
# 0.5089278179211215 + 0.0im
# time: 26.8
# 0.5090926991015898 + 0.0im
# time: 26.9
# 0.5092557209670583 + 0.0im
# time: 27.0
# 0.5094169695256265 + 0.0im
# time: 27.1
# 0.5095762441198 + 0.0im
# time: 27.2
# 0.5097334769787915 + 0.0im
# time: 27.3
# 0.5098885487039135 + 0.0im
# time: 27.4
# 0.5100413703612934 + 0.0im
# time: 27.5
# 0.5101918472774899 + 0.0im
# time: 27.6
# 0.5103398952350919 + 0.0im
# time: 27.7
# 0.510485433453807 + 0.0im
# time: 27.8
# 0.5106283880488706 + 0.0im
# time: 27.9
# 0.5107686907779337 + 0.0im
# time: 28.0
# 0.5109062797497306 + 0.0im
# time: 28.1
# 0.5110410985465274 + 0.0im
# time: 28.2
# 0.5111730978621881 + 0.0im
# time: 28.3
# 0.5113022343357323 + 0.0im
# time: 28.4
# 0.5114284711298103 + 0.0im
# time: 28.5
# 0.5115517777742538 + 0.0im
# time: 28.6
# 0.511672130221142 + 0.0im
# time: 28.7
# 0.5117895107405265 + 0.0im
# time: 28.8
# 0.5119039076809546 + 0.0im
# time: 28.9
# 0.5120153158255849 + 0.0im
# time: 29.0
# 0.5121237356674724 + 0.0im
# time: 29.1
# 0.5122291740597947 + 0.0im
# time: 29.2
# 0.5123316425373012 + 0.0im
# time: 29.3
# 0.5124311588463436 + 0.0im
# time: 29.4
# 0.5125277415242916 + 0.0im
# time: 29.5
# 0.512621417916811 + 0.0im
# time: 29.6
# 0.5127122271841993 + 0.0im
# time: 29.7
# 0.512800200569448 + 0.0im
# time: 29.8
# 0.5128853814443154 + 0.0im
# time: 29.9
# 0.5129678223436721 + 0.0im
# time: 30.0
# 0.5130475728034637 + 0.0im
# time: 30.1
# 0.5131246660861988 + 0.0im
# time: 30.2
# 0.513199156652891 + 0.0im
# time: 30.3
# 0.5132710987210453 + 0.0im
# time: 30.4
# 0.5133405488078895 + 0.0im
# time: 30.5
# 0.5134075649167792 + 0.0im
# time: 30.6
# 0.5134722065030343 + 0.0im
# time: 30.7
# 0.513534533934983 + 0.0im
# time: 30.8
# 0.5135946083571697 + 0.0im
# time: 30.9
# 0.5136524914649635 + 0.0im
# time: 31.0
# 0.5137082451497305 + 0.0im
# time: 31.1
# 0.513761931371386 + 0.0im
# time: 31.2
# 0.513813611993127 + 0.0im
# time: 31.3
# 0.5138633484697178 + 0.0im
# time: 31.4
# 0.5139112017896176 + 0.0im
# time: 31.5
# 0.5139572323267978 + 0.0im
# time: 31.6
# 0.5140014996384814 + 0.0im
# time: 31.7
# 0.5140440624357488 + 0.0im
# time: 31.8
# 0.5140849784347067 + 0.0im
# time: 31.9
# 0.5141243042461938 + 0.0im
# time: 32.0
# 0.5141620954647634 + 0.0im
# time: 32.1
# 0.5141964021677748 + 0.0im
# time: 32.2
# 0.5142317831794244 + 0.0im
# time: 32.3
# 0.5142652660818227 + 0.0im
# time: 32.4
# 0.5142975354901268 + 0.0im
# time: 32.5
# 0.5143284997243911 + 0.0im
# time: 32.6
# 0.5143582402353544 + 0.0im
# time: 32.7
# 0.5143867953010625 + 0.0im
# time: 32.8
# 0.5144142118211098 + 0.0im
# time: 32.9
# 0.5144405329196415 + 0.0im
# time: 33.0
# 0.5144658009545472 + 0.0im
# time: 33.1
# 0.5144900567977291 + 0.0im
# time: 33.2
# 0.5145133400240098 + 0.0im
# time: 33.3
# 0.5145356889388146 + 0.0im
# time: 33.4
# 0.5145571404457248 + 0.0im
# time: 33.5
# 0.5145777302471477 + 0.0im
# time: 33.6
# 0.5145974927794082 + 0.0im
# time: 33.7
# 0.5146164612530714 + 0.0im
# time: 33.8
# 0.5146346676729642 + 0.0im
# time: 33.9
# 0.5146521428700647 + 0.0im
# time: 34.0
# 0.5146689165283855 + 0.0im
# time: 34.1
# 0.5146850172155033 + 0.0im
# time: 34.2
# 0.5147004724131155 + 0.0im
# time: 34.3
# 0.5147153085473405 + 0.0im
# time: 34.4
# 0.5147295510368708 + 0.0im
# time: 34.5
# 0.5147432242893554 + 0.0im
# time: 34.6
# 0.5147563517402216 + 0.0im
# time: 34.7
# 0.5147689559161727 + 0.0im
# time: 34.8
# 0.5147810584357726 + 0.0im
# time: 34.9
# 0.5147926800471919 + 0.0im
# time: 35.0
# 0.5148038406566702 + 0.0im
# time: 35.1
# 0.5148145593584031 + 0.0im
# time: 35.2
# 0.5148248544631604 + 0.0im
# time: 35.3
# 0.5148347435270483 + 0.0im
# time: 35.4
# 0.5148442433778716 + 0.0im
# time: 35.5
# 0.5148533701557897 + 0.0im
# time: 35.6
# 0.5148621393121785 + 0.0im
# time: 35.7
# 0.5148705656453235 + 0.0im
# time: 35.8
# 0.5148786633439694 + 0.0im
# time: 35.9
# 0.5148864459933957 + 0.0im
# time: 36.0
# 0.5148939266032679 + 0.0im
# time: 36.1
# 0.5149011176298093 + 0.0im
# time: 36.2
# 0.5149080309984168 + 0.0im
# time: 36.3
# 0.5149146781252699 + 0.0im
# time: 36.4
# 0.514921069938498 + 0.0im
# time: 36.5
# 0.5149272168980858 + 0.0im
# time: 36.6
# 0.5149331290190712 + 0.0im
# time: 36.7
# 0.5149388158893058 + 0.0im
# time: 36.8
# 0.5149442866692251 + 0.0im
# time: 36.9
# 0.5149495501426324 + 0.0im
# time: 37.0
# 0.5149546147091091 + 0.0im
# time: 37.1
# 0.5149594884101644 + 0.0im
# time: 37.2
# 0.5149641789408848 + 0.0im
# time: 37.3
# 0.5149686936668912 + 0.0im
# time: 37.4
# 0.5149730396379192 + 0.0im
# time: 37.5
# 0.5149772236020975 + 0.0im
# time: 37.6
# 0.5149812520191674 + 0.0im
# time: 37.7
# 0.5149851310732753 + 0.0im
# time: 37.8
# 0.5149888666868248 + 0.0im
# time: 37.9
# 0.5149924645302091 + 0.0im
# time: 38.0
# 0.5149959300282365 + 0.0im
# time: 38.1
# 0.5149992683822394 + 0.0im
# time: 38.2
# 0.5150024847184745 + 0.0im
# time: 38.3
# 0.515005583769568 + 0.0im
# time: 38.4
# 0.5150085699401571 + 0.0im
# time: 38.5
# 0.515011447631948 + 0.0im
# time: 38.6
# 0.51501422103849 + 0.0im
# time: 38.7
# 0.5150168941812284 + 0.0im
# time: 38.8
# 0.5150194709143494 + 0.0im
# time: 38.9
# 0.5150219549326233 + 0.0im
# time: 39.0
# 0.5150243496847349 + 0.0im
# time: 39.1
# 0.5150266586841191 + 0.0im
# time: 39.2
# 0.5150288851768406 + 0.0im
# time: 39.3
# 0.5150310322882381 + 0.0im
# time: 39.4
# 0.5150331030150836 + 0.0im
# time: 39.5
# 0.5150351002321416 + 0.0im
# time: 39.6
# 0.5150370266972137 + 0.0im
# time: 39.7
# 0.5150388850564775 + 0.0im
# time: 39.8
# 0.515040677849358 + 0.0im
# time: 39.9
# 0.5150424075132398 + 0.0im
# time: 40.0
# 0.5150440763879802 + 0.0im
# time: 40.1
# 0.5150456867201676 + 0.0im
# time: 40.2
# 0.5150472406672029 + 0.0im
# time: 40.3
# 0.5150487403009625 + 0.0im
# time: 40.4
# 0.5150501876120421 + 0.0im
# time: 40.5
# 0.5150515845128084 + 0.0im
# time: 40.6
# 0.5150529328408547 + 0.0im
# time: 40.7
# 0.5150542343621891 + 0.0im
# time: 40.8
# 0.515055490774278 + 0.0im
# time: 40.9
# 0.5150567037089151 + 0.0im
# time: 41.0
# 0.5150578747350107 + 0.0im
# time: 41.1
# 0.5150590053611949 + 0.0im
# time: 41.2
# 0.5150600970383264 + 0.0im
# time: 41.3
# 0.5150611511618869 + 0.0im
# time: 41.4
# 0.515062169074266 + 0.0im
# time: 41.5
# 0.5150631520669202 + 0.0im
# time: 41.6
# 0.5150641013824998 + 0.0im
# time: 41.7
# 0.5150650182167824 + 0.0im
# time: 41.8
# 0.5150659037206472 + 0.0im
# time: 41.9
# 0.5150667590018394 + 0.0im
# time: 42.0
# 0.5150675851267116 + 0.0im
# time: 42.1
# 0.5150683831219894 + 0.0im
# time: 42.2
# 0.5150691539759303 + 0.0im
# time: 42.3
# 0.5150698986407818 + 0.0im
# time: 42.4
# 0.5150706180333432 + 0.0im
# time: 42.5
# 0.5150713130368093 + 0.0im
# time: 42.6
# 0.5150719845018576 + 0.0im
# time: 42.7
# 0.5150726332481403 + 0.0im
# time: 42.8
# 0.5150732600653324 + 0.0im
# time: 42.9
# 0.5150738657144524 + 0.0im
# time: 43.0
# 0.515074450928837 + 0.0im
# time: 43.1
# 0.5150750164153589 + 0.0im
# time: 43.2
# 0.515075562855313 + 0.0im
# time: 43.3
# 0.5150760909055164 + 0.0im
# time: 43.4
# 0.5150766011991784 + 0.0im
# time: 43.5
# 0.5150770943468267 + 0.0im
# time: 43.6
# 0.5150775709372127 + 0.0im
# time: 43.7
# 0.5150780315380004 + 0.0im
# time: 43.8
# 0.5150784766967818 + 0.0im
# time: 43.9
# 0.5150789069416093 + 0.0im
# time: 44.0
# 0.5150793227819256 + 0.0im
# time: 44.1
# 0.5150797247091012 + 0.0im
# time: 44.2
# 0.5150801131971974 + 0.0im
# time: 44.3
# 0.5150804887035979 + 0.0im
# time: 44.4
# 0.5150808516696174 + 0.0im
# time: 44.5
# 0.5150812025211092 + 0.0im
# time: 44.6
# 0.5150815416689805 + 0.0im
# time: 44.7
# 0.515081869509849 + 0.0im
# time: 44.8
# 0.5150821864264825 + 0.0im
# time: 44.9
# 0.515082492788311 + 0.0im
# time: 45.0
# 0.515082788951948 + 0.0im
# time: 45.1
# 0.5150830752616463 + 0.0im
# time: 45.2
# 0.5150833520496824 + 0.0im
# time: 45.3
# 0.5150836196369567 + 0.0im
# time: 45.4
# 0.5150838783331808 + 0.0im
# time: 45.5
# 0.5150841284374486 + 0.0im
# time: 45.6
# 0.5150843702385708 + 0.0im
# time: 45.7
# 0.5150846040153866 + 0.0im
# time: 45.8
# 0.5150848300372207 + 0.0im
# time: 45.9
# 0.5150850485641667 + 0.0im
# time: 46.0
# 0.5150852598473206 + 0.0im
# time: 46.1
# 0.5150854641293569 + 0.0im
# time: 46.2
# 0.515085661644507 + 0.0im
# time: 46.3
# 0.5150858526191755 + 0.0im
# time: 46.4
# 0.5150860372718932 + 0.0im
# time: 46.5
# 0.5150862158138991 + 0.0im
# time: 46.6
# 0.5150863884491577 + 0.0im
# time: 46.7
# 0.5150865553747587 + 0.0im
# time: 46.8
# 0.515086716781131 + 0.0im
# time: 46.9
# 0.5150868728521709 + 0.0im
# time: 47.0
# 0.5150870237656293 + 0.0im
# time: 47.1
# 0.51508716969324 + 0.0im
# time: 47.2
# 0.5150873108009109 + 0.0im
# time: 47.3
# 0.515087447248964 + 0.0im
# time: 47.4
# 0.5150875791923111 + 0.0im
# time: 47.5
# 0.5150877067806696 + 0.0im
# time: 47.6
# 0.515087830158693 + 0.0im
# time: 47.7
# 0.5150879494661791 + 0.0im
# time: 47.8
# 0.5150880648382123 + 0.0im
# time: 47.9
# 0.5150881764054336 + 0.0im
# time: 48.0
# 0.5150882842939167 + 0.0im
# time: 48.1
# 0.5150883886257104 + 0.0im
# time: 48.2
# 0.5150884895186729 + 0.0im
# time: 48.3
# 0.5150885870866827 + 0.0im
# time: 48.4
# 0.5150886814398883 + 0.0im
# time: 48.5
# 0.5150887726847228 + 0.0im
# time: 48.6
# 0.5150888609240681 + 0.0im
# time: 48.7
# 0.5150889462573599 + 0.0im
# time: 48.8
# 0.5150890287806892 + 0.0im
# time: 48.9
# 0.5150891085870364 + 0.0im
# time: 49.0
# 0.5150891857661671 + 0.0im
# time: 49.1
# 0.5150892604049588 + 0.0im
# time: 49.2
# 0.5150893325872921 + 0.0im
# time: 49.3
# 0.5150894023943519 + 0.0im
# time: 49.4
# 0.515089469904549 + 0.0im
# time: 49.5
# 0.5150895351937411 + 0.0im
# time: 49.6
# 0.5150895983352115 + 0.0im
# time: 49.7
# 0.5150896593999179 + 0.0im
# time: 49.8
# 0.515089718456224 + 0.0im
# time: 49.9
# 0.5150897755705955 + 0.0im
# time: 50.0
# 0.5150898308068911 + 0.0im
# time: 50.1
# 0.5150898842271555 + 0.0im
# time: 50.2
# 0.5150899358912077 + 0.0im
# time: 50.3
# 0.5150899858569609 + 0.0im
# time: 50.4
# 0.5150900341803749 + 0.0im
# time: 50.5
# 0.5150900809155502 + 0.0im
# time: 50.6
# 0.5150901261148586 + 0.0im
# time: 50.7
# 0.5150901698288479 + 0.0im
# time: 50.8
# 0.5150902121064618 + 0.0im
# time: 50.9
# 0.5150902529949988 + 0.0im
# time: 51.0
# 0.515090292540184 + 0.0im
# time: 51.1
# 0.5150903307862337 + 0.0im
# time: 51.2
# 0.5150903677759582 + 0.0im
# time: 51.3
# 0.5150904035506472 + 0.0im
# time: 51.4
# 0.5150904381503096 + 0.0im
# time: 51.5
# 0.5150904716136003 + 0.0im
# time: 51.6
# 0.5150905039779713 + 0.0im
# time: 51.7
# 0.51509053527946 + 0.0im
# time: 51.8
# 0.515090565553114 + 0.0im
# time: 51.9
# 0.5150905948327033 + 0.0im
# time: 52.0
# 0.5150906231509217 + 0.0im
# time: 52.1
# 0.5150906505394014 + 0.0im
# time: 52.2
# 0.5150906770286533 + 0.0im
# time: 52.3
# 0.5150907026483258 + 0.0im
# time: 52.4
# 0.515090727426908 + 0.0im
# time: 52.5
# 0.5150907513921313 + 0.0im
# time: 52.6
# 0.5150907745707164 + 0.0im
# time: 52.7
# 0.5150907969884464 + 0.0im
# time: 52.8
# 0.5150908186704145 + 0.0im
# time: 52.9
# 0.5150908396407489 + 0.0im
# time: 53.0
# 0.5150908599228327 + 0.0im
# time: 53.1
# 0.5150908795392924 + 0.0im
# time: 53.2
# 0.5150908985119698 + 0.0im
# time: 53.3
# 0.5150909168620672 + 0.0im
# time: 53.4
# 0.5150909346099476 + 0.0im
# time: 53.5
# 0.5150909517754639 + 0.0im
# time: 53.6
# 0.5150909683777442 + 0.0im
# time: 53.7
# 0.5150909844352373 + 0.0im
# time: 53.8
# 0.51509099996588 + 0.0im
# time: 53.9
# 0.515091014986944 + 0.0im
# time: 54.0
# 0.5150910295151565 + 0.0im
# time: 54.1
# 0.51509104356675 + 0.0im
# time: 54.2
# 0.5150910571572829 + 0.0im
# time: 54.3
# 0.5150910703020052 + 0.0im
# time: 54.4
# 0.5150910830154671 + 0.0im
# time: 54.5
# 0.5150910953118778 + 0.0im
# time: 54.6
# 0.5150911072048607 + 0.0im
# time: 54.7
# 0.5150911187077601 + 0.0im
# time: 54.8
# 0.5150911298332819 + 0.0im
# time: 54.9
# 0.5150911405938431 + 0.0im
# time: 55.0
# 0.5150911510014458 + 0.0im
# time: 55.1
# 0.5150911610676923 + 0.0im
# time: 55.2
# 0.5150911708036958 + 0.0im
# time: 55.3
# 0.515091180220408 + 0.0im
# time: 55.4
# 0.5150911893282137 + 0.0im
# time: 55.5
# 0.51509119813732 + 0.0im
# time: 55.6
# 0.5150912066574631 + 0.0im
# time: 55.7
# 0.5150912148981647 + 0.0im
# time: 55.8
# 0.5150912228685949 + 0.0im
# time: 55.9
# 0.5150912305776282 + 0.0im
# time: 56.0
# 0.5150912380338101 + 0.0im
# time: 56.1
# 0.5150912452454472 + 0.0im
# time: 56.2
# 0.5150912522205595 + 0.0im
# time: 56.3
# 0.515091258966958 + 0.0im
# time: 56.4
# 0.5150912654920609 + 0.0im
# time: 56.5
# 0.515091271803219 + 0.0im
# time: 56.6
# 0.5150912779073709 + 0.0im
# time: 56.7
# 0.515091283811349 + 0.0im
# time: 56.8
# 0.515091289521705 + 0.0im
# time: 56.9
# 0.5150912950447954 + 0.0im
# time: 57.0
# 0.5150913003867722 + 0.0im
# time: 57.1
# 0.5150913055535694 + 0.0im
# time: 57.2
# 0.5150913105509645 + 0.0im
# time: 57.3
# 0.515091315384398 + 0.0im
# time: 57.4
# 0.515091320059416 + 0.0im
# time: 57.5
# 0.5150913245810967 + 0.0im
# time: 57.6
# 0.5150913289545065 + 0.0im
# time: 57.7
# 0.5150913331844943 + 0.0im
# time: 57.8
# 0.5150913372758011 + 0.0im
# time: 57.9
# 0.5150913412329388 + 0.0im
# time: 58.0
# 0.5150913450603356 + 0.0im
# time: 58.1
# 0.5150913487622101 + 0.0im
# time: 58.2
# 0.5150913523426762 + 0.0im
# time: 58.3
# 0.5150913558057724 + 0.0im
# time: 58.4
# 0.5150913591553227 + 0.0im
# time: 58.5
# 0.5150913623950085 + 0.0im
# time: 58.6
# 0.5150913655284695 + 0.0im
# time: 58.7
# 0.5150913685592152 + 0.0im
# time: 58.8
# 0.5150913714905635 + 0.0im
# time: 58.9
# 0.5150913743258083 + 0.0im
# time: 59.0
# 0.5150913770680723 + 0.0im
# time: 59.1
# 0.5150913797204468 + 0.0im
# time: 59.2
# 0.5150913822858345 + 0.0im
# time: 59.3
# 0.5150913847671131 + 0.0im
# time: 59.4
# 0.5150913871670404 + 0.0im
# time: 59.5
# 0.5150913894882674 + 0.0im
# time: 59.6
# 0.5150913917334043 + 0.0im
# time: 59.7
# 0.5150913939049048 + 0.0im
# time: 59.8
# 0.5150913960052454 + 0.0im
# time: 59.9
# 0.5150913980366822 + 0.0im
# time: 60.0
# 0.5150913807883372 + 0.0im
# Total time of simulation: 160.140645133 s

# %% [markdown]
# ## Figures

# %% [markdown]
# #### Load data

# %%
using PyPlot
using DelimitedFiles
const plt = PyPlot
# Set rcParams in Julia
plt.rc("axes", linewidth=1)  # Set the linewidth of the plot axes
plt.rc("text", usetex=true)  # Enable LaTeX rendering of text

# %%
name = "test6"#"test"#A_U_0.0+Omega_3.65+zs_0.0+js_0.02"
hbar = 1.0#0.658211928e0
#nx=2
n=nx*1*2
# Out:
# 4

# %%
name1 = name#"test1"  # This is the active filename, uncomment others as needed
# Path definition (ensure 'path' is defined or replace it with the actual path)
path = "./data"  # Make sure to define or replace this with the correct path
#--------------------------------------------------------- Data from the TDNEGF code
# Loading data from text files
cspins_f = readdlm(joinpath(path, "cspins_$(name1)_jl.txt")) ;
sneq_f = readdlm(joinpath(path, "sneq_$(name1)_jl.txt"))
#seq_f = readdlm(joinpath(path, "seq_$(name1)_jl.txt"))
sc_f = readdlm(joinpath(path, "sc_$(name1)_jl.txt"))
cc_f = readdlm(joinpath(path, "cc_$(name1)_jl.txt"));
# # # #---------------------------------------------------------- Data for the density and the bond current
#bcurr1_f = readdlm(joinpath(path, "bcurr1_$(name1)_jl.txt"))
#bcurr2_f = readdlm(joinpath(path, "bcurr2_$(name1)_jl.txt"))
cden_f = readdlm(joinpath(path, "cden_$(name1)_jl.txt"));

rho_f = readdlm(joinpath(path, "rho_$(name1)_jl.txt"), ',',ComplexF64);

# %%
#cspins_f
#Int(length(sneq_f[1:2:end,1]) )
#Int(length(sneq_f[1:n:end,1]))
#4800/4[]
#rho_f[1,:]
# rhod = []
# for i in 1:1200
#     push!(rhod,reshape(rho_f[i,:],(4,4)))#reshape(rho_f[1,:],(4,4))
# end

# %%
#cspins_f
#cden_f
#sneq_f[1:2:end,1]
#sneq_f
#rhod[1]

# %%
#sneq_f
#sc_f
#sneq_f[2:2:end,1]
# plt.plot(-1im*rho_f[:,1])
# plt.plot(-1im*rho_f[:,2])
# plt.plot(-1im*rho_f[:,3])
# plt.plot(-1im*rho_f[:,4])
# plt.plot(-1im*rho_f[:,5])
# plt.plot(-1im*rho_f[:,6])
# plt.plot(-1im*rho_f[:,7])
# plt.plot(-1im*rho_f[:,8])

# %%
#plt.plot(rho_f[:,12])
#plt.plot(rho_f[:,15])

# %%
#rho_f[:,1]

# %%
#Int(length(sneq_f[1:nx:end,1]))

# %%
t_eff_sn = Int(length(sneq_f[1:nx:end,1]))
t_eff_cc = Int(length(cc_f[1:2:end])) # Int(t_end/t_step)
t_eff_sc = Int(length(sc_f[1:3:end,1]))
t_eff_cs = Int(length(cspins_f[1:Int(ceil(n/2)):end,1]))
t_eff_cd = Int(length(cden_f[1:n:end]));

# %%
sneq_ta1x = zeros(Float64,t_eff_sn, nx,3 )
#seq_ta1x = zeros(Float64,t_eff_se, n,3 )
cspins_tax = zeros(Float64,t_eff_cs, nx,3 )
cc_αt = zeros(Float64,2,t_eff_cc)
sc_αxt = zeros(Float64,2,3,t_eff_sc) ;
cden_ta1 = zeros(Float64,t_eff_cd, n) ;
#sc_αxt[1,1,:]
#sc_f[1:3:end,1]

# %%
#t_eff_sn
#n
t_eff_cd
# Out:
# 600

# %%
t_eff_sc

2pi/(KB*300)
# Out:
# 243.04448351014005

# %%
sneq_ta1x;

# %%
#sneq_f[1:nx:end,:]

# %%
#-------------- Charge current -------------------
cc_αt[1,:] = cc_f[1:2:end] # Left Charge current
cc_αt[2,:] = cc_f[2:2:end] # Right Charge current
#### X component
sc_αxt[1,1,:] = sc_f[1:3:end,1] # Left spin current
sc_αxt[2,1,:] = sc_f[1:3:end,2] # RIght spin current
## Y component
sc_αxt[1,2,:] = sc_f[2:3:end,1] 
sc_αxt[2,2,:] = sc_f[2:3:end,2]
### Z component
sc_αxt[1,3,:] = sc_f[3:3:end,1]
sc_αxt[2,3,:] = sc_f[3:3:end,2]




for i in range(1,nx)
    ##### Noneq spin density 
    sneq_ta1x[:,i,:] = sneq_f[i:nx:end,:]
    ##### Eq. spin density 
    #seq_ta1x[:,i,:] = seq_f[i:n:end,:]
    # ##### Charge density  
    #cden_ta1[:,i] = cden_f[i:n:end]
    ##### Charge Spin density  
end


for i in range(1,n)
    ##### Noneq spin density 
    #sneq_ta1x[:,i,:] = sneq_f[i:n:end,:]
    ##### Eq. spin density 
    #seq_ta1x[:,i,:] = seq_f[i:n:end,:]
    # ##### Charge density  
    cden_ta1[:,i] = cden_f[i:n:end]
    ##### Charge Spin density  
end
#### Classical spin density
for i in range(1,nx ) 
    cspins_tax[:,i,:] = cspins_f[i:Int(n//2):end,:]
end
ts_sn=t_step:t_step:t_eff_sn*t_step
ts_cc=t_step:t_step:t_eff_cc*t_step
ts_sc=t_step:t_step:t_eff_sc*t_step
ts_cs=t_step:t_step:t_eff_cs*t_step
ts_cd=t_step:t_step:t_eff_cd*t_step ;
#sc_αxt[1,1,:]
#sc_αxt[1,1,:]

# %%
#cden_ta1

# %% [markdown]
# ### Charge current

# %%
fig,axs = plt.subplots(1,1)
fs=25
#*1000000*1.25/2pi
axs.plot(ts_cc,cc_αt[1,:]*4pi,color= "green",lw = 0.5,label = raw"$\mathrm{I_R}$")
axs.plot(ts_cc,cc_αt[2,:]*4pi,color= "red",lw = 0.5,label = raw"$\mathrm{I_L}$")
axs.set_ylabel(L"$\mathrm{I\ (e\gamma/h)}$", fontsize = fs)
axs.set_xlabel(raw"$\mathrm{Time\ (fs)}$",fontsize = fs)
axs.tick_params(axis="both", which="both", labelsize=fs,direction="in", length=6,width=1)
axs.ticklabel_format(axis="y", style="sci", scilimits=(-1,2), useMathText=true)
axs.yaxis.offsetText.set_fontsize(fs)
plt.legend(frameon = false, fontsize = fs-10, loc= (0.01,  0.8))
#plt.xlim(0.0,250)
# plt.axhline(0.1,ls = "--",lw=0.5)
# plt.axhline(-0.1,ls = "--",lw=0.5)
# plt.axhline(0.0,ls = "--",lw=0.5)
#plt.axhline(0.05,ls = "--",lw=0.5)
#plt.xlim(90,120)
#plt.ylim(-2,6.5)
#plt.ylim(-0.,0.1)
#plt.ylim(0.1-1e-1,0.1+1e-1)
#plt.xlim(0,35)
plt.show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#sc_αxt

# %% [markdown]
# ### Spin Current

# %%
fig,axs = plt.subplots(1,1)
axs.plot(ts_sc,sc_αxt[1,1,:], label = raw"$\mathrm{\alpha = x}$")
axs.plot(ts_sc,sc_αxt[1,2,:], label = raw"$\mathrm{\alpha = y}$",ls=":",color="green")
axs.plot(ts_sc,sc_αxt[1,3,:], label = raw"$\mathrm{\alpha = z}$",color="red",ls=":")

# axs.plot(ts_sc,sc_αxt[2,1,:], label = raw"$\mathrm{\alpha = x}$")
# axs.plot(ts_sc,sc_αxt[2,2,:], label = raw"$\mathrm{\alpha = y}$",ls=":")
# axs.plot(ts_sc,sc_αxt[2,3,:], label = raw"$\mathrm{\alpha = z}$")
axs.set_ylabel(raw"$\mathrm{I^{S_{\alpha}}_L\ (e\gamma/h)}$", fontsize = fs)
axs.set_xlabel(raw"$\mathrm{Time\ (fs)}$",fontsize = fs)
axs.tick_params(axis="both", which="both", labelsize=fs,direction="in", length=6,width=1)
axs.ticklabel_format(axis="y", style="sci", scilimits=(-1,2), useMathText=true)
axs.yaxis.offsetText.set_fontsize(fs)
#plt.xlim(98,120)
#plt.xlim([0,22])
#axs.axhline(-0.4e-2,color="black")
#plt.ylim(-0.05,0.05)
#plt.ylim(0.1-0.02,0.1+0.02)
plt.legend(frameon = false, fontsize = fs-10, loc= (0.7,  0.7))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x7f7c5b8fff50>

# %%
#1/pi

# %% [markdown]
# ### Spin density

# %%
#sneq_ta1x[:,site,3]
#nx
#sneq_ta1x[:,:,3]

# %%
fig,axs = plt.subplots(1,1)
fs=25
site = 2
mag = sneq_ta1x[:,site,1].^2 +sneq_ta1x[:,site,2].^2 + sneq_ta1x[:,site,3].^2
axs.plot(ts_sn,sneq_ta1x[:,site,1],label = raw"$\alpha=x$")
axs.plot(ts_sn,sneq_ta1x[:,site,2],label = raw"$\alpha=y$",color="green",ls="-")
axs.plot(ts_sn,sneq_ta1x[:,site,3],label = raw"$\alpha=z$",color="red",ls="-")
#plt.axhline(0.05,ls = "--",lw=0.5)
#plt.axhline(-0.05,ls = "--",lw=0.5)
axs.set_ylabel(raw"$\langle\mathrm{\hat{S}^{\alpha}_{i}}\rangle_{\mathrm{neq}}$", fontsize = fs)
axs.set_xlabel(raw"$\mathrm{Time\ (fs)}$",fontsize = fs)
axs.tick_params(axis="both", which="both", labelsize=fs,direction="in", length=6,width=1)
axs.ticklabel_format(axis="y", style="sci", scilimits=(-1,2), useMathText=true)
axs.yaxis.offsetText.set_fontsize(fs)
#plt.axhline(2e-2)
#plt.axhline(0.0176)
#plt.xlim(90,100)
#plt.xlim(98,110)
#plt.xlim(110,120)
#plt.xlim([0,22])
#plt.ylim(-1e-6,1e-6)
plt.xlim(50, 60)
#plt.ylim(-0.5e-2,1e-2)
#plt.xlim(100,120)
#plt.axhline(0.017603845895678066*2)
plt.legend(frameon = false, fontsize = fs-10, loc= (0.7,  0.75))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x7f7c5f77b3e0>

# %%
#ts_sn

# %% [markdown]
# ### Local density

# %%
#cden_ta1[:,1]
#cden_ta1[:,1]

# %%
fig,axs =  plt.subplots(1,1)
site = 1
sites = range(1,6)
# for i in site 
#     axs.plot(ts_cd, cden_ta1[:,i]*det,label= "site=$(i)")#,alpha =1-0.2*i ) ### Charge bound current
#     axs.plot(ts_cd, cden_ta1[:,i+1]*det,label= "site=$(i+1)")#
# end
axs.plot(ts_cd/hbar, (cden_ta1[:,1]+cden_ta1[:,2])/40,label= "site=$(1)")#,alpha =1-0.2*i ) ### Charge bound current

axs.plot(ts_cd/hbar, (cden_ta1[:,4]+cden_ta1[:,3])/40,label= "site=$(2)")#(cden_ta1[:,4]+cden_ta1[:,3]),label= "site=$(2)")

axs.set_ylabel(raw"$\langle\mathrm{\hat{n}^{\alpha}_i}\rangle$", fontsize = fs)
axs.set_xlabel(raw"$\mathrm{Time\ (fs)}$",fontsize = fs)
axs.tick_params(axis="both", which="both", labelsize=fs,direction="in", length=6,width=1)
axs.ticklabel_format(axis="y", style="sci", scilimits=(-1,2), useMathText=true)
axs.yaxis.offsetText.set_fontsize(fs)
plt.legend(frameon = false, fontsize = fs-10, loc= (0.7,  0.1))
#plt.xlim(-1,40)
#plt.axhline(0.5,ls = "--",color="gray",lw = 0.5)
#plt.axhline(1.)
#plt.ylim(1-0.01,1+0.01)
#plt.ylim(-1e-2,1e-2)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x7f7c5d7e9760>

# %%
#cden_ta1

# %% [markdown]
# ### Classical magnetization

# %%
#cspins_tax
#sneq_ta1x
#.-2pi/10

# %%
#.-2pi/10 --> for T=5
#2pi/(2pi/2.3 -pi)
2pi/2
# Out:
# 3.141592653589793

# %%
fig,axs = plt.subplots(1,1)
fs=25
site = 2
axs.plot(ts_cs ,cspins_tax[:,site,1])
axs.plot(ts_cs,cspins_tax[:,site,2])
axs.plot(ts_cs,cspins_tax[:,site,3])

#axs.plot(ts_sn  ,-sneq_ta1x[:,site,1]*10,label = raw"$\alpha=x$")
#axs.plot(ts_sn ,sneq_ta1x[:,site,2]*20,label = raw"$\alpha=y$")


#axs.plot(ts_sn,sneq_f[1:2:end,2]*20,label = raw"$\alpha=x$",":")
# axs.plot(ts_sn,sneq_f[2:2:end,2]*20,label = raw"$\alpha=y$",":")
#axs.plot(ts_sn,sneq_f[1:2:end,3]*20,label = raw"$\alpha=z$",":")
#axs.plot(ts_cs,cspins_tax[:,site+2,3])
axs.set_ylabel(L"$\mathrm{M^{\alpha}}$", fontsize = fs)
#axs.set_xlabel(raw"$\mathrm{Time\ (fs)}$",fontsize = fs)
#axs.set_ylim([-5e-1,+5e-1])
#axs.set_ylim([-40e-1,40e-1])
axs.tick_params(axis="both", which="both", labelsize=fs,direction="in", length=6,width=1)
axs.ticklabel_format(axis="y", style="sci", scilimits=(-1,2), useMathText=true)
axs.yaxis.offsetText.set_fontsize(fs)
#axs.set_xlim([350,800])
#axs.set_xlim([950,1050])
#axs.set_xlim([100,120])
plt.legend(frameon = false, fontsize = fs-10, loc= (0.01,  0.8))
plt.show()
#axs.set_xlim(1800,2100)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#sneq_f
2pi/0.6
# Out:
# 0.6283185307179586

# %%
sneq_f
# Out:
# 2400×3 Matrix{Float64}:
#  5.45249e-7   1.18939e-18  2.0349e-6
#  5.45249e-7   1.1885e-18   2.0349e-6
#  5.91234e-6   1.91573e-7   2.2098e-5
#  5.91234e-6   1.91573e-7   2.2098e-5
#  2.85966e-5   1.81336e-6   0.000107182
#  2.85966e-5   1.81336e-6   0.000107182
#  8.73359e-5   8.3008e-6    0.000328735
#  8.73359e-5   8.3008e-6    0.000328735
#  0.000204763  2.60361e-5   0.000775196
#  0.000204763  2.60361e-5   0.000775196
#  0.000404258  6.4592e-5    0.0015417
#  0.000404258  6.4592e-5    0.0015417
#  0.000706529  0.000136386  0.00271856
#  ⋮
#  0.00353729   0.00807148   0.000270179
#  0.00353729   0.00807148   0.000270179
#  0.00302757   0.00828033   0.000343765
#  0.00302757   0.00828033   0.000343765
#  0.00250601   0.00845668   0.000418718
#  0.00250601   0.00845668   0.000418718
#  0.00197459   0.00859982   0.000494237
#  0.00197459   0.00859982   0.000494237
#  0.0014353    0.00870917   0.00056892
#  0.0014353    0.00870917   0.00056892
#  0.000890129  0.00878426   0.000640858
#  0.000890129  0.00878426   0.000640858

# %% [markdown]
# ## Save data

# %%
using DelimitedFiles
path = "/home/jalil2/Documents/KBA/data"
name = "GKBA_WBL_44"#"GKBA"
# Out:
# "GKBA_WBL_44"

# %%
sd = [sneq_ta1x[:,1,1] sneq_ta1x[:,1,2] sneq_ta1x[:,1,3] sneq_ta1x[:,2,1] sneq_ta1x[:,2,2] sneq_ta1x[:,2,3]]
sc = [sc_αxt[1,1,:] sc_αxt[1,2,:] sc_αxt[1,3,:] sc_αxt[2,1,:] sc_αxt[2,2,:] sc_αxt[2,3,:] ]
# Out:
# 600×6 Matrix{Float64}:
#   1.61829e-9  -2.56625e-23  4.44621e-9   1.61829e-9   1.95513e-23  4.44621e-9
#   3.11642e-9   3.32721e-10  8.622e-9     3.11642e-9   3.32721e-10  8.622e-9
#   5.32612e-9   1.34734e-9   1.51038e-8   5.32612e-9   1.34734e-9   1.51038e-8
#   6.347e-9     1.97924e-9   1.83832e-8   6.347e-9     1.97924e-9   1.83832e-8
#   7.83642e-9   3.32614e-9   2.36314e-8   7.83642e-9   3.32614e-9   2.36314e-8
#   9.16556e-9   5.01571e-9   2.91362e-8   9.16556e-9   5.01571e-9   2.91362e-8
#   1.02741e-8   7.05346e-9   3.49325e-8   1.02741e-8   7.05346e-9   3.49325e-8
#   1.10875e-8   9.41204e-9   4.09958e-8   1.10875e-8   9.41204e-9   4.09958e-8
#   1.15125e-8   1.20502e-8   4.72566e-8   1.15125e-8   1.20502e-8   4.72566e-8
#   1.14811e-8   1.49074e-8   5.36776e-8   1.14811e-8   1.49074e-8   5.36776e-8
#   1.0913e-8    1.79058e-8   6.01786e-8   1.0913e-8    1.79058e-8   6.01786e-8
#   9.76091e-9   2.09572e-8   6.67215e-8   9.76091e-9   2.09572e-8   6.67215e-8
#   7.97303e-9   2.39558e-8   7.32287e-8   7.97303e-9   2.39558e-8   7.32287e-8
#   ⋮                                                                ⋮
#  -0.0813935   -0.255235     0.755747    -0.0813935   -0.255235     0.755747
#  -0.0487624   -0.263424     0.755748    -0.0487624   -0.263424     0.755748
#  -0.0153622   -0.267458     0.755749    -0.0153622   -0.267458     0.755749
#   0.0182804   -0.267275     0.75575      0.0182804   -0.267275     0.75575
#   0.0516347   -0.262876     0.75575      0.0516347   -0.262876     0.75575
#   0.0841747   -0.254332     0.755751     0.0841747   -0.254332     0.755751
#   0.115387    -0.241777     0.755752     0.115387    -0.241777     0.755752
#   0.14478     -0.225409     0.755752     0.14478     -0.225409     0.755752
#   0.17189     -0.205485     0.755753     0.17189     -0.205485     0.755753
#   0.196289    -0.182322     0.755754     0.196289    -0.182322     0.755754
#   0.217592    -0.156283     0.755754     0.217592    -0.156283     0.755754
#   0.23566     -0.127476     0.755754     0.23566     -0.127476     0.755754

# %%
#sneq_ta1x[:,1,1] 
#sneq_ta1x

# %% [markdown]
# ### Spin density

# %%
#ccL_f = open("./data/ccL_GKBA_jl.txt", "w+") 
sd_f = open("$(path)/sd_$(name)_jl.txt", "w+") 
#writedlm(ccL_f, [sol.t*hbar 4pi*Curr_left], ' ' )
writedlm(sd_f, [ts_sn sd], ' ' )
#writedlm(ccR_f, [ts_cc -4*pi*cc_αt[1,:]], ' ' )
#close(ccL_f)
close(sd_f)

# %% [markdown]
# ### Spin current

# %%
sc_f = open("$(path)/sc_$(name)_jl.txt", "w+") 
#writedlm(ccL_f, [sol.t*hbar 4pi*Curr_left], ' ' )
writedlm(sc_f, [ts_sc sc], ' ' )
#writedlm(ccR_f, [ts_cc -4*pi*cc_αt[1,:]], ' ' )
#close(ccL_f)
close(sc_f)

# %%
#cc_αt[:,:]'
#ts_sneq

#sc_αt

# %% [markdown]
# ### Charge current

# %%
#ccL_f = open("./data/ccL_GKBA_jl.txt", "w+") 
cc_f = open("$(path)/cc_$(name)_jl.txt", "w+") 
#writedlm(ccL_f, [sol.t*hbar 4pi*Curr_left], ' ' )
writedlm(cc_f, [ts_cc -4*pi*cc_αt'], ' ' )
#writedlm(ccR_f, [ts_cc -4*pi*cc_αt[1,:]], ' ' )
#close(ccL_f)
close(cc_f)

# %% [markdown]
# ### Local density

# %%
#using DelimitedFiles
#ccL_f = open("./data/ccL_GKBA_jl.txt", "w+") 
cden_f = open("$(path)/cd_$(name)_jl.txt", "w+") 
#writedlm(ccL_f, [sol.t*hbar 4pi*Curr_left], ' ' )
writedlm(cden_f, [ts_cd cden_ta1], ' ' )
#close(ccL_f)
close(cden_f)

# %%
#cden_ta1
